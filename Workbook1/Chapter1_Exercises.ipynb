# %% [markdown]
# #Exercise 1

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
print('Hello world!') # the variable "P" is in Capital letter
# Out:
# Hello world!

# %%
print('Hello world!') #missing open parenthesis (
# Out:
# Hello world!

# %%
print('Hello world!') #missing quotation mark (')
# Out:
# Hello world!

# %%
print('Hello world!') #extra quotation mark (')
# Out:
# Hello world!

# %% [markdown]
# # Exercise 2

# %%
x = 43
x = x + 1
print(x)

#44
# Out:
# 44

# %% [markdown]
# #Exercise 3

# %%
x = 43
x = x + 1
print(x)
# variable X is  undefined
# Out:
# 44
