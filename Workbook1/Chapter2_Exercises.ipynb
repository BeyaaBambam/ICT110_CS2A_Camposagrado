# %% [markdown]
# #Exercise 1

# %% [markdown]
# Write a program that uses input to prompt a user for their name and then welcomes them.
# ```
# Enter your name: Chuck
# Hello Chuck
# ```
#
# [PEW] E2.2

# %%
name = input ("Enter your name: ")
print ("hello", name)
# Out:
# Enter your name: bea
# hello bea

# %% [markdown]
# #Exercise 2

# %% [markdown]
# Write a program to prompt the user for hours and rate per hour to compute gross pay.
# ```
# Enter Hours: 35
# Enter Rate: 2.75
# Pay: 96.25
# ```
#
# [PEW] E2.3

# %%
hours= float (input ("Enter Hours: "))
rate= float (input ("Enter Rate:"))
pay = hours*rate
print( 'Pay',pay)
# Out:
# Enter Hours: 100
# Enter Rate:2
# Pay 200.0

# %% [markdown]
# #Exercise 3

# %% [markdown]
# Assume that we execute the following assignment statements:
# ```python
# width = 17
# height = 12.0
# ```
# For each of the following expressions, write the value of the expression and the type (of the value of the expression).
# ```python
# width//2
# width/2.0
# height/3
# 1 + 2 * 5
# ```
#
# [PEW] E2.4

# %%
width = 17
r=width //2
print (r)
print ('int')
# Out:
# 8
# int

# %%
width = 17
r=width /2.0
print(r)
print ('int')
# Out:
# 8.5
# int

# %%
height=12.0
r=height/3
print (r)
print ('float')
# Out:
# 4.0
# float

# %%
a=1+2*5
print(a)
print ('int')
# Out:
# 11
# int

# %%
n=int(input ('Enter a number: '))
square = n**2
print('The square of ',n, 'is',square)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-1-92f4afa03239> in <cell line: 1>()
# ----> 1 n=int(input ('Enter a number: '))
#       2 square = n**2
#       3 print('The square of ',n, 'is',square)
#
# /usr/local/lib/python3.10/dist-packages/ipykernel/kernelbase.py in raw_input(self, prompt)
#     849                 "raw_input was called, but this frontend does not support input requests."
#     850             )
# --> 851         return self._input_request(str(prompt),
#     852             self._parent_ident,
#     853             self._parent_header,
#
# /usr/local/lib/python3.10/dist-packages/ipykernel/kernelbase.py in _input_request(self, prompt, ident, parent, password)
#     893             except KeyboardInterrupt:
#     894                 # re-raise KeyboardInterrupt, to truncate traceback
# --> 895                 raise KeyboardInterrupt("Interrupted by user") from None
#     896             except Exception as e:
#     897                 self.log.warning("Invalid Message:", exc_info=True)
#
# KeyboardInterrupt: Interrupted by user

# %% [markdown]
# #Exercise 4

# %% [markdown]
# Enter a number: 3
# The square of 3 is 9

# %%
n=int(input ('Enter a number: '))
square = n**2
print('The square of ',n, 'is',square)
# Out:
# Enter a number: 10
# The square of  10 is 100

# %% [markdown]
# #Challenge

# %% [markdown]
# Write a program which prompts the user for a Celsius temperature, convert the temperature to Fahrenheit, and print out the converted temperature.
#
# [PEW] E2.5

# %%
cel=float (input ('Enter temperature in Celcius:'))
far = (cel *9/5)+32
print('The temperatue in Fahrenheit is: ',far)
# Out:
# Enter temperature in Celcius:77
# The temperatue in Fahrenheit is:  170.6
