# %% [markdown]
# ####TXT

# %%
file_handle = open('bbb.txt','w')
print(file_handle)
# Out:
# <_io.TextIOWrapper name='bbb.txt' mode='w' encoding='UTF-8'>

# %%
file_handle = open('bbb.txt','r')
print(file_handle)
# Out:
# <_io.TextIOWrapper name='bbb.txt' mode='r' encoding='UTF-8'>

# %%
file_handle = open('mbox.txt','w')
print(file_handle)
# Out:
# <_io.TextIOWrapper name='mbox.txt' mode='w' encoding='UTF-8'>

# %%
file_handle = open('mbox.txt','r')
print(file_handle)
# Out:
# <_io.TextIOWrapper name='mbox.txt' mode='r' encoding='UTF-8'>

# %%
file_handle = open('file.txt','r')
print(file_handle)
# Out:
# <_io.TextIOWrapper name='file.txt' mode='r' encoding='UTF-8'>

# %%
file_handle = open('file.txt','w')
print(file_handle)
# Out:
# <_io.TextIOWrapper name='file.txt' mode='w' encoding='UTF-8'>

# %% [markdown]
# ####Exercise 1

# %% [markdown]
# Write a program to read through a file and print the contents of the file (line by line) all in upper case.
#
# from [PEW] E8-1

# %%
filename = input('Enter filename: ')
try:
    basa = open(filename, 'r')
    for line in basa:
        print(line.upper().strip())
    basa.close()
except FileNotFoundError:
    print(f"File '{filename}' not found.")
# Out:
# Enter filename: bbb.txt
# File 'bbb.txt' not found.

# %% [markdown]
# ####Exercise 2

# %% [markdown]
# Write a program to read through a file and output the number of lines in a file.
#
# adapted from [PEW]

# %%
filename = input('Enter filename: ')
count = 0
try:
    basa = open(filename, 'r')
    for line in basa:
        count += 1
    print('{} has {} lines.'.format(filename, count))
    basa.close()
except FileNotFoundError:
    print(f"File '{filename}' not found.")
# Out:
# Enter filename: file.txt
# file.txt has 7 lines.

# %% [markdown]
# ####CHALLENGE
# from [PEW] E8-2

# %% [markdown]
# Write a program to prompt for a file name, and then read through the file and look for lines of the form:

# %% [markdown]
# When you encounter a line that starts with "X-DSPAM-Confidence:" pull apart the line to extract the floating-point number on the line. Count these lines and then compute the total of the spam confidence values from these lines. When you reach the end of the file, print out the average spam confidence.

# %%
fileName = input("Enter the file name: ")
total = 0.0
count = 0
try :
    basa = open(fileName, 'r')
    for line in basa :
        if line.startswith("X-DSPAM-Confidence:"):
                confidence = float(line.split(":")[1].strip())
                total += confidence
                count += 1
    if count > 0:
        average = total / count
        print("Average spam confidence:",average)
    else:
        print("No lines with spam confidence found.")
    basa.close();
except FileNotFoundError:
    print(f"File '{fileName}' not found.")
# Out:
# Enter the file name: mbox.txt
# Average spam confidence: 0.8475
